# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('party_in_nyc.csv', encoding="latin1")

# %%
df.columns
# Out:
# Index(['Created Date', 'Closed Date', 'Location Type', 'Incident Zip', 'City',
#        'Borough', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df
# Out:
#                Created Date          Closed Date               Location Type  \
# 0       2015-12-31 00:01:15  2015-12-31 03:48:04            Store/Commercial
# 1       2015-12-31 00:02:48  2015-12-31 04:36:13            Store/Commercial
# 2       2015-12-31 00:03:25  2015-12-31 00:40:15  Residential Building/House
# 3       2015-12-31 00:03:26  2015-12-31 01:53:38  Residential Building/House
# 4       2015-12-31 00:05:10  2015-12-31 03:49:10  Residential Building/House
# ...                     ...                  ...                         ...
# 225409  2016-12-31 23:53:57  2017-01-01 00:01:41            Store/Commercial
# 225410  2016-12-31 23:55:01  2017-01-01 02:05:06  Residential Building/House
# 225411  2016-12-31 23:56:20  2017-01-01 13:34:00  Residential Building/House
# 225412  2016-12-31 23:56:41  2017-01-01 03:49:12  Residential Building/House
# 225413  2016-12-31 23:58:52  2017-01-01 00:59:52  Residential Building/House
#
# ...

# %%
df1=df.groupby(['City'])['Created Date'].count()
df1
# Out:
# City
# ARVERNE                  510
# ASTORIA                 3456
# BAYSIDE                  232
# BELLEROSE                160
# BREEZY POINT               1
# BRONX                  47673
# BROOKLYN               68909
# CAMBRIA HEIGHTS          171
# CENTRAL PARK              48
# COLLEGE POINT            529
# CORONA                  2395
# EAST ELMHURST           1258
# ELMHURST                1260
# FAR ROCKAWAY            1535
# FLORAL PARK               13
# FLUSHING                1761
# FOREST HILLS             532
# FRESH MEADOWS            613
# GLEN OAKS                123
# HOLLIS                   670
# HOWARD BEACH             438
# JACKSON HEIGHTS         1229
# JAMAICA                 4041
# KEW GARDENS              364
# LITTLE NECK              131
# LONG ISLAND CITY        1072
# MASPETH                  409
# MIDDLE VILLAGE           217
# NEW HYDE PARK             11
# NEW YORK               64112
# OAKLAND GARDENS          113
# OZONE PARK              1494
# ...

# %%
df1.plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %%
lat_min = df['Latitude'].min()
lat_max = df['Latitude'].max()
long_min = df['Longitude'].min()
long_max = df['Longitude'].max()
print("Rettangolo di latitudine e longitudine considerato nel dataset:")
print("Latitudine minima:", lat_min)
print("Latitudine massima:", lat_max)
print("Longitudine minima:", long_min)
print("Longitudine massima:", long_max)
# Out:
# Rettangolo di latitudine e longitudine considerato nel dataset:
# Latitudine minima: 40.498819681472185
# Latitudine massima: 40.91217840308113
# Longitudine minima: -74.25127710072611
# Longitudine massima: -73.70230256557906

# %%
case_private=df['Location Type']=='Residential Building/House'
case_private.count()
# Out:
# 225414

# %%
sns.countplot(data=df, x='Borough', palette='muted')
# Out:
# <Axes: xlabel='Borough', ylabel='count'>

# %%
sns.countplot(data=df, x='Borough', hue='Location Type', palette='muted')
# Out:
# <Axes: xlabel='Borough', ylabel='count'>
