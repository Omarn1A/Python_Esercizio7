# %%
import pandas as pd
import os

import seaborn as sns
df=pd.read_csv('metal_bands_2017.csv', encoding="latin1")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'band_name', 'fans', 'formed', 'origin', 'split',
#        'style'],
#       dtype='object')

# %%
df
# Out:
#       Unnamed: 0        band_name  fans formed          origin split  \
# 0              0      Iron Maiden  4195   1975  United Kingdom     -
# 1              1            Opeth  4147   1990          Sweden  1990
# 2              2        Metallica  3712   1981             USA     -
# 3              3         Megadeth  3105   1983             USA  1983
# 4              4      Amon Amarth  3054   1988          Sweden     -
# ...          ...              ...   ...    ...             ...   ...
# 4995        4995            Atara     0   2006          France  2006
# 4996        4996       Avicularia     0   2003         Croatia     -
# 4997        4997            Awake     0   2006  United Kingdom  2006
# 4998        4998           Axatak     0   1983       Australia  1988
# 4999        4999  Axis Of Despair     0   2014          Sweden  2014
#
#                                                  style
# 0                      New wave of british heavy,Heavy
# ...

# %%
sns.histplot(data=df, x='band_name', y='fans', bins=50)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='band_name', ylabel='fans'>

# %%
df_Progressive=df['style']=='Progressive'
df_Thrash=df['style']=='Thrash'
df2=df.loc[df_Progressive | df_Thrash]
df_plot=df2.groupby(['origin'])
sns.barplot(data=df2, x='fans', y='origin')
# Out:
# <Axes: xlabel='fans', ylabel='origin'>

# %%
df=df.replace('-',None)
pd.to_numeric(df['formed'])
# Out:
# 0       1975.0
# 1       1990.0
# 2       1981.0
# 3       1983.0
# 4       1988.0
#          ...
# 4995    2006.0
# 4996    2003.0
# 4997    2006.0
# 4998    1983.0
# 4999    2014.0
# Name: formed, Length: 5000, dtype: float64

# %%
sns.histplot(data=df,x='
# Out:
#       Unnamed: 0                    band_name  fans formed          origin  \
# 4440        4440                     Theories     2   2010             USA
# 4441        4441  Those Who Bring The Torture     2   2007          Sweden
# 4442        4442             Throes Of Sanity     2      -             USA
# 4443        4443                       Titaan     2   2015           Italy
# 4444        4444                      Tribune     2   2004          Canada
# ...          ...                          ...   ...    ...             ...
# 4995        4995                        Atara     0   2006          France
# 4996        4996                   Avicularia     0   2003         Croatia
# 4997        4997                        Awake     0   2006  United Kingdom
# 4998        4998                       Axatak     0   1983       Australia
# 4999        4999              Axis Of Despair     0   2014          Sweden
#
#      split                       style
# ...
